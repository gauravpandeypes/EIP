# %%
from __future__ import print_function
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10
import numpy as np
import os

# %%
# Training parameters
batch_size = 128 # orig paper trained all networks with batch_size=128
epochs = 60
data_augmentation = True
num_classes = 10

# Subtracting pixel mean improves accuracy
subtract_pixel_mean = True

n = 3

# Model version
# Orig paper: version = 1 (ResNet v1), Improved ResNet: version = 2 (ResNet v2)
version = 1

# Computed depth from supplied model parameter n
depth = n * 6 + 2

# Model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)

# %%
# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %%
# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)

# %%
# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
def lr_schedule(epoch):
    lr = 1e-3

    if epoch > 40:
        lr *= 1e-3
    elif epoch > 30:
        lr *= 1e-2
    elif epoch > 25:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
  
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %%
def resnet_v1(input_shape, depth, num_classes=10):
    
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, 44 in [a])')
    # Start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
model = resnet_v1(input_shape=input_shape, depth=depth)

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=lr_schedule(0)),
              metrics=['accuracy'])
# Out:
# Learning rate:  0.001

# %%
model.summary()
print(model_type)
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 32, 32, 16)   448         input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 32, 32, 16)   64          conv2d_43[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 32, 32, 16)   0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 32, 32, 16)   2320        activation_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 32, 32, 16)   64          conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 32, 32, 16)   0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 32, 32, 16)   2320        activation_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 32, 32, 16)   64          conv2d_45[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 32, 32, 16)   0           activation_39[0][0]
#                                                                  batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 32, 32, 16)   0           add_19[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 32, 32, 16)   2320        activation_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 32, 32, 16)   64          conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 32, 32, 16)   0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 32, 32, 16)   2320        activation_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 32, 32, 16)   64          conv2d_47[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 32, 32, 16)   0           activation_41[0][0]
#                                                                  batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 32, 32, 16)   0           add_20[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 32, 32, 16)   2320        activation_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 32, 32, 16)   64          conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 32, 32, 16)   0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 32, 32, 16)   2320        activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 32, 32, 16)   64          conv2d_49[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 32, 32, 16)   0           activation_43[0][0]
#                                                                  batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 32, 32, 16)   0           add_21[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 16, 16, 32)   4640        activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 16, 16, 32)   128         conv2d_50[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 16, 16, 32)   0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 16, 16, 32)   9248        activation_46[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 16, 16, 32)   544         activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 16, 16, 32)   128         conv2d_51[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 16, 16, 32)   0           conv2d_52[0][0]
#                                                                  batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 16, 16, 32)   0           add_22[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 16, 16, 32)   9248        activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 16, 16, 32)   128         conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 16, 16, 32)   0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 16, 16, 32)   9248        activation_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 16, 16, 32)   128         conv2d_54[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 16, 16, 32)   0           activation_47[0][0]
#                                                                  batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 16, 16, 32)   0           add_23[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 16, 16, 32)   9248        activation_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 16, 16, 32)   128         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 16, 16, 32)   0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 16, 16, 32)   9248        activation_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 16, 16, 32)   128         conv2d_56[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 16, 16, 32)   0           activation_49[0][0]
#                                                                  batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 16, 16, 32)   0           add_24[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 8, 8, 64)     18496       activation_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 8, 8, 64)     256         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 8, 8, 64)     0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 8, 8, 64)     36928       activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 8, 8, 64)     2112        activation_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 8, 8, 64)     256         conv2d_58[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 8, 8, 64)     0           conv2d_59[0][0]
#                                                                  batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 8, 8, 64)     0           add_25[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 8, 8, 64)     36928       activation_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 8, 8, 64)     256         conv2d_60[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 8, 8, 64)     0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 8, 8, 64)     36928       activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 8, 8, 64)     256         conv2d_61[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 8, 8, 64)     0           activation_53[0][0]
#                                                                  batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 8, 8, 64)     0           add_26[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 8, 8, 64)     36928       activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 8, 8, 64)     256         conv2d_62[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 8, 8, 64)     0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 8, 8, 64)     36928       activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 8, 8, 64)     256         conv2d_63[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 8, 8, 64)     0           activation_55[0][0]
#                                                                  batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 8, 8, 64)     0           add_27[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 1, 1, 64)     0           activation_57[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 64)           0           average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 10)           650         flatten_3[0][0]
# ==================================================================================================
# Total params: 274,442
# Trainable params: 273,066
# Non-trainable params: 1,376
# __________________________________________________________________________________________________
# ResNet20v1

# %%
# Prepare model model saving directory.
save_dir = './content/cifar10model' + 'saved_models'
model_name = 'cifar10_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = save_dir + model_name

# %%
# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# %%
# Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.,
        # set range for random channel shifts
        channel_shift_range=0.,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                        validation_data=(x_test, y_test),
                        epochs=epochs, verbose=1, workers=4,
                        callbacks=callbacks)
# Out:
# Using real-time data augmentation.
# Epoch 1/60
# Learning rate:  0.001
# 391/391 [==============================] - 53s 136ms/step - loss: 1.6472 - acc: 0.4542 - val_loss: 1.5666 - val_acc: 0.4843
#
# Epoch 00001: val_acc improved from -inf to 0.48430, saving model to ./content/cifar10modelsaved_modelscifar10_ResNet20v1_model.001.h5
# Epoch 2/60
# Learning rate:  0.001
# 391/391 [==============================] - 44s 113ms/step - loss: 1.2762 - acc: 0.5941 - val_loss: 1.6257 - val_acc: 0.5135
#
# Epoch 00002: val_acc improved from 0.48430 to 0.51350, saving model to ./content/cifar10modelsaved_modelscifar10_ResNet20v1_model.002.h5
# Epoch 3/60
# Learning rate:  0.001
# 391/391 [==============================] - 44s 112ms/step - loss: 1.0892 - acc: 0.6674 - val_loss: 1.3702 - val_acc: 0.6014
#
# Epoch 00003: val_acc improved from 0.51350 to 0.60140, saving model to ./content/cifar10modelsaved_modelscifar10_ResNet20v1_model.003.h5
# Epoch 4/60
# Learning rate:  0.001
# 391/391 [==============================] - 43s 110ms/step - loss: 0.9716 - acc: 0.7075 - val_loss: 1.5062 - val_acc: 0.5727
#
# Epoch 00004: val_acc did not improve from 0.60140
# Epoch 5/60
# Learning rate:  0.001
# 391/391 [==============================] - 44s 112ms/step - loss: 0.8919 - acc: 0.7385 - val_loss: 1.4363 - val_acc: 0.5907
#
# Epoch 00005: val_acc did not improve from 0.60140
# Epoch 6/60
# Learning rate:  0.001
# 391/391 [==============================] - 45s 114ms/step - loss: 0.8267 - acc: 0.7635 - val_loss: 1.0245 - val_acc: 0.7084
#
# Epoch 00006: val_acc improved from 0.60140 to 0.70840, saving model to ./content/cifar10modelsaved_modelscifar10_ResNet20v1_model.006.h5
# Epoch 7/60
# Learning rate:  0.001
# 391/391 [==============================] - 43s 111ms/step - loss: 0.7823 - acc: 0.7790 - val_loss: 0.8954 - val_acc: 0.7510
#
# Epoch 00007: val_acc improved from 0.70840 to 0.75100, saving model to ./content/cifar10modelsaved_modelscifar10_ResNet20v1_model.007.h5
# Epoch 8/60
# Learning rate:  0.001
# 391/391 [==============================] - 44s 112ms/step - loss: 0.7502 - acc: 0.7907 - val_loss: 1.0002 - val_acc: 0.7179
#
# Epoch 00008: val_acc did not improve from 0.75100
# Epoch 9/60
# Learning rate:  0.001
# 391/391 [==============================] - 43s 110ms/step - loss: 0.7138 - acc: 0.8030 - val_loss: 1.1772 - val_acc: 0.6974
#
# Epoch 00009: val_acc did not improve from 0.75100
# Epoch 10/60
# Learning rate:  0.001
# 391/391 [==============================] - 44s 112ms/step - loss: 0.6844 - acc: 0.8127 - val_loss: 1.1795 - val_acc: 0.6956
#
# Epoch 00010: val_acc did not improve from 0.75100
# Epoch 11/60
# Learning rate:  0.001
# 391/391 [==============================] - 44s 111ms/step - loss: 0.6633 - acc: 0.8195 - val_loss: 0.8262 - val_acc: 0.7781
#
# Epoch 00011: val_acc improved from 0.75100 to 0.77810, saving model to ./content/cifar10modelsaved_modelscifar10_ResNet20v1_model.011.h5
# Epoch 12/60
# Learning rate:  0.001
# 391/391 [==============================] - 43s 111ms/step - loss: 0.6462 - acc: 0.8257 - val_loss: 1.1278 - val_acc: 0.7034
#
# Epoch 00012: val_acc did not improve from 0.77810
# Epoch 13/60
# Learning rate:  0.001
# 391/391 [==============================] - 43s 111ms/step - loss: 0.6233 - acc: 0.8357 - val_loss: 0.7440 - val_acc: 0.7994
#
# Epoch 00013: val_acc improved from 0.77810 to 0.79940, saving model to ./content/cifar10modelsaved_modelscifar10_ResNet20v1_model.013.h5
# Epoch 14/60
# Learning rate:  0.001
# 391/391 [==============================] - 44s 113ms/step - loss: 0.6123 - acc: 0.8382 - val_loss: 0.6800 - val_acc: 0.8155
#
# Epoch 00014: val_acc improved from 0.79940 to 0.81550, saving model to ./content/cifar10modelsaved_modelscifar10_ResNet20v1_model.014.h5
# Epoch 15/60
# Learning rate:  0.001
# 391/391 [==============================] - 44s 113ms/step - loss: 0.5914 - acc: 0.8455 - val_loss: 0.7567 - val_acc: 0.7976
#
# Epoch 00015: val_acc did not improve from 0.81550
# Epoch 16/60
# Learning rate:  0.001
# 391/391 [==============================] - 43s 111ms/step - loss: 0.5756 - acc: 0.8511 - val_loss: 1.0047 - val_acc: 0.7237
#
# Epoch 00016: val_acc did not improve from 0.81550
# Epoch 17/60
# Learning rate:  0.001
# 391/391 [==============================] - 45s 116ms/step - loss: 0.5675 - acc: 0.8538 - val_loss: 0.7597 - val_acc: 0.8004
#
# Epoch 00017: val_acc did not improve from 0.81550
# Epoch 18/60
# Learning rate:  0.001
# 391/391 [==============================] - 44s 114ms/step - loss: 0.5535 - acc: 0.8587 - val_loss: 0.7833 - val_acc: 0.7871
#
# Epoch 00018: val_acc did not improve from 0.81550
# Epoch 19/60
# Learning rate:  0.001
# 391/391 [==============================] - 45s 114ms/step - loss: 0.5464 - acc: 0.8619 - val_loss: 0.7719 - val_acc: 0.7966
#
# Epoch 00019: val_acc did not improve from 0.81550
# Epoch 20/60
# Learning rate:  0.001
# 391/391 [==============================] - 45s 115ms/step - loss: 0.5362 - acc: 0.8661 - val_loss: 0.9983 - val_acc: 0.7471
#
# Epoch 00020: val_acc did not improve from 0.81550
# Epoch 21/60
# Learning rate:  0.001
# 391/391 [==============================] - 45s 115ms/step - loss: 0.5222 - acc: 0.8706 - val_loss: 0.9544 - val_acc: 0.7535
#
# Epoch 00021: val_acc did not improve from 0.81550
# Epoch 22/60
# Learning rate:  0.001
# 391/391 [==============================] - 45s 116ms/step - loss: 0.5128 - acc: 0.8740 - val_loss: 0.8468 - val_acc: 0.7791
#
# Epoch 00022: val_acc did not improve from 0.81550
# Epoch 23/60
# Learning rate:  0.001
# 391/391 [==============================] - 45s 116ms/step - loss: 0.5101 - acc: 0.8746 - val_loss: 0.6962 - val_acc: 0.8191
#
# Epoch 00023: val_acc improved from 0.81550 to 0.81910, saving model to ./content/cifar10modelsaved_modelscifar10_ResNet20v1_model.023.h5
# Epoch 24/60
# Learning rate:  0.001
# 391/391 [==============================] - 45s 115ms/step - loss: 0.4994 - acc: 0.8790 - val_loss: 0.8313 - val_acc: 0.7857
#
# Epoch 00024: val_acc did not improve from 0.81910
# Epoch 25/60
# Learning rate:  0.001
# 391/391 [==============================] - 45s 114ms/step - loss: 0.5000 - acc: 0.8776 - val_loss: 0.9410 - val_acc: 0.7541
#
# Epoch 00025: val_acc did not improve from 0.81910
# Epoch 26/60
# Learning rate:  0.001
# 391/391 [==============================] - 45s 115ms/step - loss: 0.4887 - acc: 0.8827 - val_loss: 1.1334 - val_acc: 0.7448
#
# Epoch 00026: val_acc did not improve from 0.81910
# Epoch 27/60
# Learning rate:  0.0001
# 391/391 [==============================] - 45s 115ms/step - loss: 0.4142 - acc: 0.9100 - val_loss: 0.5285 - val_acc: 0.8742
#
# Epoch 00027: val_acc improved from 0.81910 to 0.87420, saving model to ./content/cifar10modelsaved_modelscifar10_ResNet20v1_model.027.h5
# Epoch 28/60
# Learning rate:  0.0001
# 391/391 [==============================] - 44s 113ms/step - loss: 0.3875 - acc: 0.9182 - val_loss: 0.5336 - val_acc: 0.8731
#
# Epoch 00028: val_acc did not improve from 0.87420
# Epoch 29/60
# Learning rate:  0.0001
# 391/391 [==============================] - 44s 113ms/step - loss: 0.3778 - acc: 0.9219 - val_loss: 0.5175 - val_acc: 0.8788
#
# Epoch 00029: val_acc improved from 0.87420 to 0.87880, saving model to ./content/cifar10modelsaved_modelscifar10_ResNet20v1_model.029.h5
# Epoch 30/60
# Learning rate:  0.0001
# 391/391 [==============================] - 44s 113ms/step - loss: 0.3641 - acc: 0.9258 - val_loss: 0.5202 - val_acc: 0.8770
#
# Epoch 00030: val_acc did not improve from 0.87880
# Epoch 31/60
# Learning rate:  0.0001
# 391/391 [==============================] - 45s 114ms/step - loss: 0.3604 - acc: 0.9266 - val_loss: 0.5161 - val_acc: 0.8789
#
# Epoch 00031: val_acc improved from 0.87880 to 0.87890, saving model to ./content/cifar10modelsaved_modelscifar10_ResNet20v1_model.031.h5
# Epoch 32/60
# Learning rate:  1e-05
# 391/391 [==============================] - 44s 113ms/step - loss: 0.3499 - acc: 0.9320 - val_loss: 0.5075 - val_acc: 0.8821
#
# Epoch 00032: val_acc improved from 0.87890 to 0.88210, saving model to ./content/cifar10modelsaved_modelscifar10_ResNet20v1_model.032.h5
# Epoch 33/60
# Learning rate:  1e-05
# 391/391 [==============================] - 45s 116ms/step - loss: 0.3477 - acc: 0.9316 - val_loss: 0.5066 - val_acc: 0.8829
#
# Epoch 00033: val_acc improved from 0.88210 to 0.88290, saving model to ./content/cifar10modelsaved_modelscifar10_ResNet20v1_model.033.h5
# Epoch 34/60
# Learning rate:  1e-05
# 391/391 [==============================] - 45s 115ms/step - loss: 0.3472 - acc: 0.9323 - val_loss: 0.5050 - val_acc: 0.8828
#
# Epoch 00034: val_acc did not improve from 0.88290
# Epoch 35/60
# Learning rate:  1e-05
# 391/391 [==============================] - 45s 114ms/step - loss: 0.3457 - acc: 0.9312 - val_loss: 0.5074 - val_acc: 0.8828
#
# Epoch 00035: val_acc did not improve from 0.88290
# Epoch 36/60
# Learning rate:  1e-05
# 391/391 [==============================] - 45s 114ms/step - loss: 0.3427 - acc: 0.9328 - val_loss: 0.5074 - val_acc: 0.8832
#
# Epoch 00036: val_acc improved from 0.88290 to 0.88320, saving model to ./content/cifar10modelsaved_modelscifar10_ResNet20v1_model.036.h5
# Epoch 37/60
# Learning rate:  1e-05
# 391/391 [==============================] - 45s 114ms/step - loss: 0.3456 - acc: 0.9335 - val_loss: 0.5050 - val_acc: 0.8832
#
# Epoch 00037: val_acc did not improve from 0.88320
# Epoch 38/60
# Learning rate:  1e-05
# 391/391 [==============================] - 45s 116ms/step - loss: 0.3442 - acc: 0.9330 - val_loss: 0.5039 - val_acc: 0.8846
#
# Epoch 00038: val_acc improved from 0.88320 to 0.88460, saving model to ./content/cifar10modelsaved_modelscifar10_ResNet20v1_model.038.h5
# Epoch 39/60
# Learning rate:  1e-05
# 391/391 [==============================] - 45s 115ms/step - loss: 0.3439 - acc: 0.9319 - val_loss: 0.5064 - val_acc: 0.8846
#
# Epoch 00039: val_acc did not improve from 0.88460
# Epoch 40/60
# Learning rate:  1e-05
# 391/391 [==============================] - 45s 115ms/step - loss: 0.3404 - acc: 0.9338 - val_loss: 0.5044 - val_acc: 0.8842
#
# Epoch 00040: val_acc did not improve from 0.88460
# Epoch 41/60
# Learning rate:  1e-05
# 391/391 [==============================] - 46s 116ms/step - loss: 0.3417 - acc: 0.9339 - val_loss: 0.5048 - val_acc: 0.8846
#
# Epoch 00041: val_acc did not improve from 0.88460
# Epoch 42/60
# Learning rate:  1e-06
# 391/391 [==============================] - 46s 117ms/step - loss: 0.3390 - acc: 0.9350 - val_loss: 0.5057 - val_acc: 0.8837
#
# Epoch 00042: val_acc did not improve from 0.88460
# Epoch 43/60
# Learning rate:  1e-06
# 391/391 [==============================] - 45s 115ms/step - loss: 0.3391 - acc: 0.9336 - val_loss: 0.5059 - val_acc: 0.8834
#
# Epoch 00043: val_acc did not improve from 0.88460
# Epoch 44/60
# Learning rate:  1e-06
# 391/391 [==============================] - 45s 115ms/step - loss: 0.3366 - acc: 0.9344 - val_loss: 0.5049 - val_acc: 0.8844
#
# Epoch 00044: val_acc did not improve from 0.88460
# Epoch 45/60
# Learning rate:  1e-06
# 391/391 [==============================] - 45s 115ms/step - loss: 0.3387 - acc: 0.9347 - val_loss: 0.5047 - val_acc: 0.8837
#
# Epoch 00045: val_acc did not improve from 0.88460
# Epoch 46/60
# Learning rate:  1e-06
# 391/391 [==============================] - 45s 115ms/step - loss: 0.3393 - acc: 0.9339 - val_loss: 0.5048 - val_acc: 0.8839
#
# Epoch 00046: val_acc did not improve from 0.88460
# Epoch 47/60
# Learning rate:  1e-06
# 391/391 [==============================] - 46s 117ms/step - loss: 0.3406 - acc: 0.9330 - val_loss: 0.5047 - val_acc: 0.8842
#
# Epoch 00047: val_acc did not improve from 0.88460
# Epoch 48/60
# Learning rate:  1e-06
# 391/391 [==============================] - 45s 114ms/step - loss: 0.3402 - acc: 0.9340 - val_loss: 0.5053 - val_acc: 0.8839
#
# Epoch 00048: val_acc did not improve from 0.88460
# Epoch 49/60
# Learning rate:  1e-06
# 391/391 [==============================] - 44s 113ms/step - loss: 0.3387 - acc: 0.9336 - val_loss: 0.5056 - val_acc: 0.8837
#
# Epoch 00049: val_acc did not improve from 0.88460
# Epoch 50/60
# Learning rate:  1e-06
# 391/391 [==============================] - 44s 113ms/step - loss: 0.3397 - acc: 0.9343 - val_loss: 0.5043 - val_acc: 0.8842
#
# Epoch 00050: val_acc did not improve from 0.88460
# Epoch 51/60
# Learning rate:  1e-06
# 391/391 [==============================] - 45s 114ms/step - loss: 0.3384 - acc: 0.9341 - val_loss: 0.5036 - val_acc: 0.8833
#
# Epoch 00051: val_acc did not improve from 0.88460
# Epoch 52/60
# Learning rate:  1e-06
# 391/391 [==============================] - 45s 116ms/step - loss: 0.3396 - acc: 0.9329 - val_loss: 0.5037 - val_acc: 0.8848
#
# Epoch 00052: val_acc improved from 0.88460 to 0.88480, saving model to ./content/cifar10modelsaved_modelscifar10_ResNet20v1_model.052.h5
# Epoch 53/60
# Learning rate:  1e-06
# 391/391 [==============================] - 45s 116ms/step - loss: 0.3389 - acc: 0.9347 - val_loss: 0.5047 - val_acc: 0.8839
#
# Epoch 00053: val_acc did not improve from 0.88480
# Epoch 54/60
# Learning rate:  1e-06
# 391/391 [==============================] - 46s 116ms/step - loss: 0.3369 - acc: 0.9342 - val_loss: 0.5040 - val_acc: 0.8842
#
# Epoch 00054: val_acc did not improve from 0.88480
# Epoch 55/60
# Learning rate:  1e-06
# 391/391 [==============================] - 45s 116ms/step - loss: 0.3393 - acc: 0.9340 - val_loss: 0.5047 - val_acc: 0.8843
#
# Epoch 00055: val_acc did not improve from 0.88480
# Epoch 56/60
# Learning rate:  1e-06
# 391/391 [==============================] - 45s 116ms/step - loss: 0.3387 - acc: 0.9345 - val_loss: 0.5054 - val_acc: 0.8833
#
# Epoch 00056: val_acc did not improve from 0.88480
# Epoch 57/60
# Learning rate:  1e-06
# 391/391 [==============================] - 44s 114ms/step - loss: 0.3396 - acc: 0.9336 - val_loss: 0.5054 - val_acc: 0.8843
#
# Epoch 00057: val_acc did not improve from 0.88480
# Epoch 58/60
# Learning rate:  1e-06
# 391/391 [==============================] - 45s 115ms/step - loss: 0.3361 - acc: 0.9346 - val_loss: 0.5047 - val_acc: 0.8840
#
# Epoch 00058: val_acc did not improve from 0.88480
# Epoch 59/60
# Learning rate:  1e-06
# 391/391 [==============================] - 45s 114ms/step - loss: 0.3394 - acc: 0.9347 - val_loss: 0.5035 - val_acc: 0.8843
#
# Epoch 00059: val_acc did not improve from 0.88480
# Epoch 60/60
# Learning rate:  1e-06
# 391/391 [==============================] - 45s 115ms/step - loss: 0.3376 - acc: 0.9345 - val_loss: 0.5045 - val_acc: 0.8842
#
# Epoch 00060: val_acc did not improve from 0.88480

# %%
# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# 10000/10000 [==============================] - 3s 256us/step
# Test loss: 0.5045470998764038
# Test accuracy: 0.8842

# %%
from keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions
from keras.preprocessing import image
import numpy as np
import cv2
from skimage import io
from google.colab.patches import cv2_imshow

# %%
imagelist1=[
#aeroplane
"https://external-content.duckduckgo.com/iu/?u=http%3A%2F%2Fi.dailymail.co.uk%2Fi%2Fpix%2F2014%2F03%2F07%2Farticle-0-04D0FCC00000044D-711_964x546.jpg&f=1&nofb=1",
#automobile
"https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse2.mm.bing.net%2Fth%3Fid%3DOIP.-McqOWblQU-Prji6NPq-cgHaFj%26pid%3DApi&f=1",
#bird
"https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Fc1.staticflickr.com%2F1%2F418%2F18262633594_3563a9c5a2_b.jpg&f=1&nofb=1",
#cat
"https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse4.mm.bing.net%2Fth%3Fid%3DOIP.2mggqeJ4NZV5yiwdvcq5YwHaFj%26pid%3DApi&f=1",
#deer
"https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse1.mm.bing.net%2Fth%3Fid%3DOIP.sTyIyhetlzgIFo2GYbhMWQHaEW%26pid%3DApi&f=1",
#dog
"http://images1.fanpop.com/images/photos/1900000/Puppy-3-dogs-1993798-1024-768.jpg",
#frog       
"https://www.petmd.com/sites/default/files/frog-care-101.jpg",
#horse       
"https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse3.mm.bing.net%2Fth%3Fid%3DOIP.Y0WzgRcmS4ns-sJI9mew1gHaHa%26pid%3DApi&f=1",
#ship  
"https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse3.mm.bing.net%2Fth%3Fid%3DOIP.txqct3wOYRHYm77YCgcXPQHaEO%26pid%3DApi&f=1",
#truck     
"https://www.tatamotors.com/wp-content/uploads/2019/03/13071813/icv-truck.jpg"]

# %%
def gradcam(imagelist,models):

  for img in imagelist:

      #4. Rescale image to 224x224x3 (VGG's expectation, why?)
      #5. Use expand_dims to convert image to a batch of size 1
      #6. Preprocesing normalizes our input image by subtracting mean RGB values
      print(img)
      img = io.imread(img)
      img = cv2.resize(img, dsize=(32, 32), interpolation=cv2.INTER_CUBIC)
      x = image.img_to_array(img)
      x = np.expand_dims(x, axis=0)
      
      x = preprocess_input(x)
      x /= 255


      #1. We get the predictions for the image
      #2. We take the topmost class index
      #3. Take output from the final convolutional layer
      preds = model.predict(x)
      class_idx = np.argmax(preds[0])
      print(class_idx)
      class_output = model.output[:, class_idx]
      last_conv_layer = model.get_layer("activation_57")


      #1. Compute the gradient of the class output value with respect to the feature map
      #2. Pool the gradients over all the axies leaving out the channel dimension
      #3. Weigh the output feature map with the computed gradient values
      grads = K.gradients(class_output, last_conv_layer.output)[0]
      print(grads.shape)
      pooled_grads = K.mean(grads, axis=(0, 1, 2))
      print(pooled_grads.shape)
      iterate = K.function([model.input], [pooled_grads, last_conv_layer.output[0]])

      pooled_grads_value, conv_layer_output_value = iterate([x])

      for i in range(64):
        conv_layer_output_value[:, :, i] *= pooled_grads_value[i]


      
      #1. Average the weighted feature map along the channel dimension resulting in a heat map of size 14x14 
      #2. Normalize the heat map to make the values between 0 and 1
      heatmap = np.mean(conv_layer_output_value, axis = -1)
      print(conv_layer_output_value.shape)
      print(heatmap.shape)
      heatmap = np.maximum(heatmap, 0)
      heatmap /= np.max(heatmap)


      #Show the results
      img = cv2.resize(img, dsize=(224, 224), interpolation=cv2.INTER_CUBIC)
      heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
      heatmap = np.uint8(255 * heatmap)
      heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
      superimposed_img = cv2.addWeighted(img, 0.8, heatmap, 0.9, 0)
      from google.colab.patches import cv2_imshow
      cv2_imshow(img)
      cv2_imshow(superimposed_img)

# %%
gradcam(imagelist=imagelist1,models=model)
# Out:
# https://external-content.duckduckgo.com/iu/?u=http%3A%2F%2Fi.dailymail.co.uk%2Fi%2Fpix%2F2014%2F03%2F07%2Farticle-0-04D0FCC00000044D-711_964x546.jpg&f=1&nofb=1
# 0
# (?, 8, 8, 64)
# (64,)
# (8, 8, 64)
# (8, 8)
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F9471E16940>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F9471E169B0>
# https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse2.mm.bing.net%2Fth%3Fid%3DOIP.-McqOWblQU-Prji6NPq-cgHaFj%26pid%3DApi&f=1
# 1
# (?, 8, 8, 64)
# (64,)
# (8, 8, 64)
# (8, 8)
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F9471E2C160>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F9471E2C438>
# https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Fc1.staticflickr.com%2F1%2F418%2F18262633594_3563a9c5a2_b.jpg&f=1&nofb=1
# 2
# (?, 8, 8, 64)
# (64,)
# (8, 8, 64)
# (8, 8)
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F9471E1E550>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F9471E1E630>
# https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse4.mm.bing.net%2Fth%3Fid%3DOIP.2mggqeJ4NZV5yiwdvcq5YwHaFj%26pid%3DApi&f=1
# 3
# (?, 8, 8, 64)
# (64,)
# (8, 8, 64)
# (8, 8)
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F9471E3C5C0>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F9471E3C550>
# https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse1.mm.bing.net%2Fth%3Fid%3DOIP.sTyIyhetlzgIFo2GYbhMWQHaEW%26pid%3DApi&f=1
# 4
# (?, 8, 8, 64)
# (64,)
# (8, 8, 64)
# (8, 8)
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F9471DDAFD0>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F9471EA83C8>
# http://images1.fanpop.com/images/photos/1900000/Puppy-3-dogs-1993798-1024-768.jpg
# 5
# (?, 8, 8, 64)
# (64,)
# (8, 8, 64)
# (8, 8)
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F9471DF0518>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F9471DE11D0>
# https://www.petmd.com/sites/default/files/frog-care-101.jpg
# 6
# (?, 8, 8, 64)
# (64,)
# (8, 8, 64)
# (8, 8)
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F9471DF0400>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F9471DF06D8>
# https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse3.mm.bing.net%2Fth%3Fid%3DOIP.Y0WzgRcmS4ns-sJI9mew1gHaHa%26pid%3DApi&f=1
# 7
# (?, 8, 8, 64)
# (64,)
# (8, 8, 64)
# (8, 8)
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F9471D848D0>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F9471D845C0>
# https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse3.mm.bing.net%2Fth%3Fid%3DOIP.txqct3wOYRHYm77YCgcXPQHaEO%26pid%3DApi&f=1
# 8
# (?, 8, 8, 64)
# (64,)
# (8, 8, 64)
# (8, 8)
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F9471D8E7F0>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F9471D8E128>
# https://www.tatamotors.com/wp-content/uploads/2019/03/13071813/icv-truck.jpg
# 9
# (?, 8, 8, 64)
# (64,)
# (8, 8, 64)
# (8, 8)
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F9471DA7F28>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F9471DA7390>
